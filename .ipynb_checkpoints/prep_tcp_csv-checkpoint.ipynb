# %% [markdown]
# # Partie 1 : MLP

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import matplotlib.pyplot as plt
import numpy as np
import pickle
import glob
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "./tcpDDOS.csv"

initial_df = pd.read_csv(file_path)

initial_df
# Out:
#            No.       Time         Source    Destination Protocol  Length  \
# 0            1   0.000000  192.168.233.3  192.168.233.4      TCP      74
# 1            2   0.000065  192.168.233.4  192.168.233.3      TCP      74
# 2            3   0.000356  192.168.233.3  192.168.233.4      TCP      66
# 3            4   0.003793  192.168.233.3  192.168.233.4      TCP     103
# 4            5   0.003837  192.168.233.4  192.168.233.3      TCP      66
# ...        ...        ...            ...            ...      ...     ...
# 426593  426594  33.491317  192.168.233.3  192.168.233.4      TCP   17442
# 426594  426595  33.491334  192.168.233.4  192.168.233.3      TCP      66
# 426595  426596  33.491405  192.168.233.3  192.168.233.4      TCP   47850
# 426596  426597  33.491437  192.168.233.3  192.168.233.4      TCP   20338
# 426597  426598  33.491457  192.168.233.4  192.168.233.3      TCP      66
#
#                                                      Info         label  \
# 0       52120  >  5201 [SYN] Seq=0 Win=64240 Len=0 MSS...  2.245683e+09
# 1       5201  >  52120 [SYN, ACK] Seq=0 Ack=1 Win=6516...  3.722622e+09
# 2       52120  >  5201 [ACK] Seq=1 Ack=1 Win=64256 Len...  2.245683e+09
# 3       52120  >  5201 [PSH, ACK] Seq=1 Ack=1 Win=6425...  2.245683e+09
# 4       5201  >  52120 [ACK] Seq=1 Ack=38 Win=65152 Le...  3.722622e+09
# ...                                                   ...           ...
# 426593  52136  >  5201 [ACK] Seq=815472166 Ack=1 Win=6...  2.245717e+09
# 426594  5201  >  52136 [ACK] Seq=1 Ack=815489542 Win=3...  3.722656e+09
# 426595  52136  >  5201 [PSH, ACK] Seq=815489542 Ack=1 ...  2.245717e+09
# 426596  52136  >  5201 [ACK] Seq=815537326 Ack=1 Win=6...  2.245717e+09
# 426597  5201  >  52136 [ACK] Seq=1 Ack=815557598 Win=3...  3.722656e+09
#
#         dest port  source port                   protocol  flow duration  \
# 0            5201        52120       eth:ethertype:ip:tcp       0.000000
# 1           52120         5201       eth:ethertype:ip:tcp       0.000065
# 2            5201        52120       eth:ethertype:ip:tcp       0.000291
# 3            5201        52120  eth:ethertype:ip:tcp:data       0.003437
# 4           52120         5201       eth:ethertype:ip:tcp       0.000044
# ...           ...          ...                        ...            ...
# 426593       5201        52136  eth:ethertype:ip:tcp:data       0.000175
# 426594      52136         5201       eth:ethertype:ip:tcp       0.000017
# 426595       5201        52136  eth:ethertype:ip:tcp:data       0.000071
# 426596       5201        52136  eth:ethertype:ip:tcp:data       0.000031
# 426597      52136         5201       eth:ethertype:ip:tcp       0.000020
#
#         Total Fwd Packets  Total Length of Bwd Packets  Fwd Packet Length Max  \
# 0                     NaN                          NaN                      0
# 1                0.000065                          NaN                      0
# 2                0.000291                          NaN                      0
# 3                     NaN                          NaN                     37
# 4                0.000044                          NaN                      0
# ...                   ...                          ...                    ...
# 426593                NaN                          NaN                  17376
# 426594           0.000017                          NaN                      0
# 426595                NaN                          NaN                  47784
# 426596                NaN                          NaN                  20272
# 426597           0.000020                          NaN                      0
#
#         Fwd Header Length  Bwd Header Length ACK Flag Count URG Flag Count  \
# 0                      40                 74        Not set        Not set
# 1                      40                 74            Set        Not set
# 2                      32                 66            Set        Not set
# 3                      32                103            Set        Not set
# 4                      32                 66            Set        Not set
# ...                   ...                ...            ...            ...
# 426593                 32              17442            Set        Not set
# 426594                 32                 66            Set        Not set
# 426595                 32              47850            Set        Not set
# 426596                 32              20338            Set        Not set
# 426597                 32                 66            Set        Not set
#
#         Subflow Bwd Packets
# 0                       NaN
# 1                  0.000065
# 2                  0.000291
# 3                       NaN
# 4                  0.000044
# ...                     ...
# 426593                  NaN
# 426594             0.000017
# 426595                  NaN
# 426596                  NaN
# 426597             0.000020
#
# [426598 rows x 20 columns]

# %%
empty_label_rows = initial_df[initial_df['label'].isna()]

# Print the rows with empty or NaN labels
print("Rows with empty or NaN labels:")
print(empty_label_rows)
# Out:
# Rows with empty or NaN labels:
#            No.       Time           Source    Destination Protocol  Length  \
# 66070    66071   8.228322   41.146.181.222  192.168.233.4      TCP     174
# 66071    66072   8.228426  146.243.107.168  192.168.233.4      TCP     174
# 66072    66073   8.233974   192.183.47.127  192.168.233.4      TCP     174
# 66073    66074   8.233975    89.82.221.232  192.168.233.4      TCP     174
# 66074    66075   8.233975    73.76.215.151  192.168.233.4      TCP     174
# ...        ...        ...              ...            ...      ...     ...
# 317058  317059  22.714220     54.96.167.68  192.168.233.4      TCP     174
# 317059  317060  22.714220    77.167.28.186  192.168.233.4      TCP     174
# 317060  317061  22.714244   129.55.232.100  192.168.233.4      TCP     174
# 317061  317062  22.714244   102.119.164.26  192.168.233.4      TCP     174
# 317062  317063  22.714244     250.9.107.28  192.168.233.4      TCP     174
#
#                                                      Info  label  dest port  \
# 66070            2915  >  4040 [SYN] Seq=0 Win=64 Len=120    NaN       4040
# 66071            2916  >  4040 [SYN] Seq=0 Win=64 Len=120    NaN       4040
# 66072            2917  >  4040 [SYN] Seq=0 Win=64 Len=120    NaN       4040
# 66073            2918  >  4040 [SYN] Seq=0 Win=64 Len=120    NaN       4040
# 66074            2919  >  4040 [SYN] Seq=0 Win=64 Len=120    NaN       4040
# ...                                                   ...    ...        ...
# 317058           3685  >  4044 [SYN] Seq=0 Win=64 Len=120    NaN       4044
# 317059           3686  >  4044 [SYN] Seq=0 Win=64 Len=120    NaN       4044
# 317060           3687  >  4044 [SYN] Seq=0 Win=64 Len=120    NaN       4044
# 317061           3688  >  4044 [SYN] Seq=0 Win=64 Len=120    NaN       4044
# 317062  3689  >  4044 [SYN] Seq=0 Win=64 Len=120 [TCP ...    NaN       4044
#
#         source port                   protocol  flow duration  \
# 66070          2915  eth:ethertype:ip:tcp:data            0.0
# 66071          2916  eth:ethertype:ip:tcp:data            0.0
# 66072          2917  eth:ethertype:ip:tcp:data            0.0
# 66073          2918  eth:ethertype:ip:tcp:data            0.0
# 66074          2919  eth:ethertype:ip:tcp:data            0.0
# ...             ...                        ...            ...
# 317058         3685  eth:ethertype:ip:tcp:data            0.0
# 317059         3686  eth:ethertype:ip:tcp:data            0.0
# 317060         3687  eth:ethertype:ip:tcp:data            0.0
# 317061         3688  eth:ethertype:ip:tcp:data            0.0
# 317062         3689       eth:ethertype:ip:tcp            0.0
#
#         Total Fwd Packets  Total Length of Bwd Packets  Fwd Packet Length Max  \
# 66070                 NaN                          NaN                    120
# 66071                 NaN                          NaN                    120
# 66072                 NaN                          NaN                    120
# 66073                 NaN                          NaN                    120
# 66074                 NaN                          NaN                    120
# ...                   ...                          ...                    ...
# 317058                NaN                          NaN                    120
# 317059                NaN                          NaN                    120
# 317060                NaN                          NaN                    120
# 317061                NaN                          NaN                    120
# 317062                NaN                          NaN                    120
#
#         Fwd Header Length  Bwd Header Length ACK Flag Count URG Flag Count  \
# 66070                  20                174        Not set        Not set
# 66071                  20                174        Not set        Not set
# 66072                  20                174        Not set        Not set
# 66073                  20                174        Not set        Not set
# 66074                  20                174        Not set        Not set
# ...                   ...                ...            ...            ...
# 317058                 20                174        Not set        Not set
# 317059                 20                174        Not set        Not set
# 317060                 20                174        Not set        Not set
# 317061                 20                174        Not set        Not set
# 317062                 20                174        Not set        Not set
#
#         Subflow Bwd Packets
# 66070                   NaN
# 66071                   NaN
# 66072                   NaN
# 66073                   NaN
# 66074                   NaN
# ...                     ...
# 317058                  NaN
# 317059                  NaN
# 317060                  NaN
# 317061                  NaN
# 317062                  NaN
#
# [148576 rows x 20 columns]

# %%
label_df = pd.DataFrame(initial_df['label'])

label_df.head(50)

label_counts = initial_df['label']

labels_attack = label_counts[label_counts.isna()]
labels_benign = label_counts[~label_counts.isna()]

labels_benign
# Out:
# 0         2.245683e+09
# 1         3.722622e+09
# 2         2.245683e+09
# 3         2.245683e+09
# 4         3.722622e+09
#               ...
# 426593    2.245717e+09
# 426594    3.722656e+09
# 426595    2.245717e+09
# 426596    2.245717e+09
# 426597    3.722656e+09
# Name: label, Length: 278022, dtype: float64

# %%
def z_score(input_df):
    # copy the data
    df_z_scaled = input_df

    # apply normalization techniques
    for column in df_z_scaled.columns:
        df_z_scaled[column] = (df_z_scaled[column] -
                               df_z_scaled[column].mean()) / df_z_scaled[column].std()    

    # view normalized data   
    return df_z_scaled

# %% [markdown]
# ### data

# %%
new_df = initial_df.copy()
new_df
# Out:
#            No.       Time         Source    Destination Protocol  Length  \
# 0            1   0.000000  192.168.233.3  192.168.233.4      TCP      74
# 1            2   0.000065  192.168.233.4  192.168.233.3      TCP      74
# 2            3   0.000356  192.168.233.3  192.168.233.4      TCP      66
# 3            4   0.003793  192.168.233.3  192.168.233.4      TCP     103
# 4            5   0.003837  192.168.233.4  192.168.233.3      TCP      66
# ...        ...        ...            ...            ...      ...     ...
# 426593  426594  33.491317  192.168.233.3  192.168.233.4      TCP   17442
# 426594  426595  33.491334  192.168.233.4  192.168.233.3      TCP      66
# 426595  426596  33.491405  192.168.233.3  192.168.233.4      TCP   47850
# 426596  426597  33.491437  192.168.233.3  192.168.233.4      TCP   20338
# 426597  426598  33.491457  192.168.233.4  192.168.233.3      TCP      66
#
#                                                      Info         label  \
# 0       52120  >  5201 [SYN] Seq=0 Win=64240 Len=0 MSS...  2.245683e+09
# 1       5201  >  52120 [SYN, ACK] Seq=0 Ack=1 Win=6516...  3.722622e+09
# 2       52120  >  5201 [ACK] Seq=1 Ack=1 Win=64256 Len...  2.245683e+09
# 3       52120  >  5201 [PSH, ACK] Seq=1 Ack=1 Win=6425...  2.245683e+09
# 4       5201  >  52120 [ACK] Seq=1 Ack=38 Win=65152 Le...  3.722622e+09
# ...                                                   ...           ...
# 426593  52136  >  5201 [ACK] Seq=815472166 Ack=1 Win=6...  2.245717e+09
# 426594  5201  >  52136 [ACK] Seq=1 Ack=815489542 Win=3...  3.722656e+09
# 426595  52136  >  5201 [PSH, ACK] Seq=815489542 Ack=1 ...  2.245717e+09
# 426596  52136  >  5201 [ACK] Seq=815537326 Ack=1 Win=6...  2.245717e+09
# 426597  5201  >  52136 [ACK] Seq=1 Ack=815557598 Win=3...  3.722656e+09
#
#         dest port  source port                   protocol  flow duration  \
# 0            5201        52120       eth:ethertype:ip:tcp       0.000000
# 1           52120         5201       eth:ethertype:ip:tcp       0.000065
# 2            5201        52120       eth:ethertype:ip:tcp       0.000291
# 3            5201        52120  eth:ethertype:ip:tcp:data       0.003437
# 4           52120         5201       eth:ethertype:ip:tcp       0.000044
# ...           ...          ...                        ...            ...
# 426593       5201        52136  eth:ethertype:ip:tcp:data       0.000175
# 426594      52136         5201       eth:ethertype:ip:tcp       0.000017
# 426595       5201        52136  eth:ethertype:ip:tcp:data       0.000071
# 426596       5201        52136  eth:ethertype:ip:tcp:data       0.000031
# 426597      52136         5201       eth:ethertype:ip:tcp       0.000020
#
#         Total Fwd Packets  Total Length of Bwd Packets  Fwd Packet Length Max  \
# 0                     NaN                          NaN                      0
# 1                0.000065                          NaN                      0
# 2                0.000291                          NaN                      0
# 3                     NaN                          NaN                     37
# 4                0.000044                          NaN                      0
# ...                   ...                          ...                    ...
# 426593                NaN                          NaN                  17376
# 426594           0.000017                          NaN                      0
# 426595                NaN                          NaN                  47784
# 426596                NaN                          NaN                  20272
# 426597           0.000020                          NaN                      0
#
#         Fwd Header Length  Bwd Header Length ACK Flag Count URG Flag Count  \
# 0                      40                 74        Not set        Not set
# 1                      40                 74            Set        Not set
# 2                      32                 66            Set        Not set
# 3                      32                103            Set        Not set
# 4                      32                 66            Set        Not set
# ...                   ...                ...            ...            ...
# 426593                 32              17442            Set        Not set
# 426594                 32                 66            Set        Not set
# 426595                 32              47850            Set        Not set
# 426596                 32              20338            Set        Not set
# 426597                 32                 66            Set        Not set
#
#         Subflow Bwd Packets
# 0                       NaN
# 1                  0.000065
# 2                  0.000291
# 3                       NaN
# 4                  0.000044
# ...                     ...
# 426593                  NaN
# 426594             0.000017
# 426595                  NaN
# 426596                  NaN
# 426597             0.000020
#
# [426598 rows x 20 columns]

# %%
# Replace empty strings and NaN values in the 'label' column with 'attack'
new_df['label'] = new_df['label'].fillna('attack')

# Replace all remaining labels (excluding 'attack') with 'benign'
new_df.loc[new_df['label'] != 'attack', 'label'] = 'benign'

print(new_df.head())
# Out:
#    No.      Time         Source    Destination Protocol  Length  \
# 0    1  0.000000  192.168.233.3  192.168.233.4      TCP      74
# 1    2  0.000065  192.168.233.4  192.168.233.3      TCP      74
# 2    3  0.000356  192.168.233.3  192.168.233.4      TCP      66
# 3    4  0.003793  192.168.233.3  192.168.233.4      TCP     103
# 4    5  0.003837  192.168.233.4  192.168.233.3      TCP      66
#
#                                                 Info   label  dest port  \
# 0  52120  >  5201 [SYN] Seq=0 Win=64240 Len=0 MSS...  benign       5201
# 1  5201  >  52120 [SYN, ACK] Seq=0 Ack=1 Win=6516...  benign      52120
# 2  52120  >  5201 [ACK] Seq=1 Ack=1 Win=64256 Len...  benign       5201
# 3  52120  >  5201 [PSH, ACK] Seq=1 Ack=1 Win=6425...  benign       5201
# 4  5201  >  52120 [ACK] Seq=1 Ack=38 Win=65152 Le...  benign      52120
#
#    source port                   protocol  flow duration  Total Fwd Packets  \
# 0        52120       eth:ethertype:ip:tcp       0.000000                NaN
# 1         5201       eth:ethertype:ip:tcp       0.000065           0.000065
# 2        52120       eth:ethertype:ip:tcp       0.000291           0.000291
# 3        52120  eth:ethertype:ip:tcp:data       0.003437                NaN
# 4         5201       eth:ethertype:ip:tcp       0.000044           0.000044
#
#    Total Length of Bwd Packets  Fwd Packet Length Max  Fwd Header Length  \
# 0                          NaN                      0                 40
# 1                          NaN                      0                 40
# 2                          NaN                      0                 32
# 3                          NaN                     37                 32
# 4                          NaN                      0                 32
#
#    Bwd Header Length ACK Flag Count URG Flag Count  Subflow Bwd Packets
# 0                 74        Not set        Not set                  NaN
# 1                 74            Set        Not set             0.000065
# 2                 66            Set        Not set             0.000291
# 3                103            Set        Not set                  NaN
# 4                 66            Set        Not set             0.000044

# %%
label_counts = new_df['label'].value_counts()
label_counts
# Out:
# benign    278022
# attack    148576
# Name: label, dtype: int64

# %% [markdown]
# ### pre-sampling

# %%
plt.figure(figsize=(8, 8))
plt.pie(label_counts, labels=label_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
#SAMPLING

attack_sample_df_dic = {}
attack_df = new_df[ new_df['label'] != 'benign' ]
for label in label_df['index']:
    #5% of attacks
    attack_sample_df_dic[label] = attack_df[attack_df['label'] == label][:1000]

attack_sample_df = pd.concat(attack_sample_df_dic)
# 10% attacks vs 90% benign
BENIGN_sample_df = new_df[new_df['label'] == 'benign'][:19000]

sampled_df_1 =  pd.concat([attack_sample_df, BENIGN_sample_df])

# %%
sampled_df_1
# Out:
#                    No.      Time           Source    Destination Protocol  \
# (attack, 66070)  66071  8.228322   41.146.181.222  192.168.233.4      TCP
# (attack, 66071)  66072  8.228426  146.243.107.168  192.168.233.4      TCP
# (attack, 66072)  66073  8.233974   192.183.47.127  192.168.233.4      TCP
# (attack, 66073)  66074  8.233975    89.82.221.232  192.168.233.4      TCP
# (attack, 66074)  66075  8.233975    73.76.215.151  192.168.233.4      TCP
# ...                ...       ...              ...            ...      ...
# 18995            18996  1.328329    192.168.233.4  192.168.233.3      TCP
# 18996            18997  1.328360    192.168.233.3  192.168.233.4      TCP
# 18997            18998  1.328400    192.168.233.4  192.168.233.3      TCP
# 18998            18999  1.328404    192.168.233.3  192.168.233.4      TCP
# 18999            19000  1.328430    192.168.233.4  192.168.233.3      TCP
#
#                  Length                                               Info  \
# (attack, 66070)     174           2915  >  4040 [SYN] Seq=0 Win=64 Len=120
# (attack, 66071)     174           2916  >  4040 [SYN] Seq=0 Win=64 Len=120
# (attack, 66072)     174           2917  >  4040 [SYN] Seq=0 Win=64 Len=120
# (attack, 66073)     174           2918  >  4040 [SYN] Seq=0 Win=64 Len=120
# (attack, 66074)     174           2919  >  4040 [SYN] Seq=0 Win=64 Len=120
# ...                 ...                                                ...
# 18995                66  5201  >  52136 [ACK] Seq=1 Ack=333074950 Win=3...
# 18996             23234  52136  >  5201 [PSH, ACK] Seq=333074950 Ack=1 ...
# 18997                66  5201  >  52136 [ACK] Seq=1 Ack=333098118 Win=3...
# 18998             33370  52136  >  5201 [ACK] Seq=333098118 Ack=1 Win=6...
# 18999                66  5201  >  52136 [ACK] Seq=1 Ack=333131422 Win=3...
#
#                   label  dest port  source port                   protocol  \
# (attack, 66070)  attack       4040         2915  eth:ethertype:ip:tcp:data
# (attack, 66071)  attack       4040         2916  eth:ethertype:ip:tcp:data
# (attack, 66072)  attack       4040         2917  eth:ethertype:ip:tcp:data
# (attack, 66073)  attack       4040         2918  eth:ethertype:ip:tcp:data
# (attack, 66074)  attack       4040         2919  eth:ethertype:ip:tcp:data
# ...                 ...        ...          ...                        ...
# 18995            benign      52136         5201       eth:ethertype:ip:tcp
# 18996            benign       5201        52136  eth:ethertype:ip:tcp:data
# 18997            benign      52136         5201       eth:ethertype:ip:tcp
# 18998            benign       5201        52136  eth:ethertype:ip:tcp:data
# 18999            benign      52136         5201       eth:ethertype:ip:tcp
#
#                  flow duration  Total Fwd Packets  \
# (attack, 66070)       0.000000                NaN
# (attack, 66071)       0.000000                NaN
# (attack, 66072)       0.000000                NaN
# (attack, 66073)       0.000000                NaN
# (attack, 66074)       0.000000                NaN
# ...                        ...                ...
# 18995                 0.000033           0.000033
# 18996                 0.000031                NaN
# 18997                 0.000040           0.000040
# 18998                 0.000004                NaN
# 18999                 0.000027           0.000027
#
#                  Total Length of Bwd Packets  Fwd Packet Length Max  \
# (attack, 66070)                          NaN                    120
# (attack, 66071)                          NaN                    120
# (attack, 66072)                          NaN                    120
# (attack, 66073)                          NaN                    120
# (attack, 66074)                          NaN                    120
# ...                                      ...                    ...
# 18995                                    NaN                      0
# 18996                                    NaN                  23168
# 18997                                    NaN                      0
# 18998                                    NaN                  33304
# 18999                                    NaN                      0
#
#                  Fwd Header Length  Bwd Header Length ACK Flag Count  \
# (attack, 66070)                 20                174        Not set
# (attack, 66071)                 20                174        Not set
# (attack, 66072)                 20                174        Not set
# (attack, 66073)                 20                174        Not set
# (attack, 66074)                 20                174        Not set
# ...                            ...                ...            ...
# 18995                           32                 66            Set
# 18996                           32              23234            Set
# 18997                           32                 66            Set
# 18998                           32              33370            Set
# 18999                           32                 66            Set
#
#                 URG Flag Count  Subflow Bwd Packets
# (attack, 66070)        Not set                  NaN
# (attack, 66071)        Not set                  NaN
# (attack, 66072)        Not set                  NaN
# (attack, 66073)        Not set                  NaN
# (attack, 66074)        Not set                  NaN
# ...                        ...                  ...
# 18995                  Not set             0.000033
# 18996                  Not set                  NaN
# 18997                  Not set             0.000040
# 18998                  Not set                  NaN
# 18999                  Not set             0.000027
#
# [20000 rows x 20 columns]

# %% [markdown]
# ### post-sampling

# %%
sampled_label_counts = sampled_df_1['label'].value_counts()

# Create a pie chart for the sampled dataset
plt.figure(figsize=(8, 8))
plt.pie(sampled_label_counts, labels=sampled_label_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Sampled Label Distribution')
plt.axis('equal')  
plt.show()

# %% [markdown]
# ### Preprocessing

# %%
df = sampled_df_1.copy()

# %%
df
# Out:
#                    No.      Time           Source    Destination Protocol  \
# (attack, 66070)  66071  8.228322   41.146.181.222  192.168.233.4      TCP
# (attack, 66071)  66072  8.228426  146.243.107.168  192.168.233.4      TCP
# (attack, 66072)  66073  8.233974   192.183.47.127  192.168.233.4      TCP
# (attack, 66073)  66074  8.233975    89.82.221.232  192.168.233.4      TCP
# (attack, 66074)  66075  8.233975    73.76.215.151  192.168.233.4      TCP
# ...                ...       ...              ...            ...      ...
# 18995            18996  1.328329    192.168.233.4  192.168.233.3      TCP
# 18996            18997  1.328360    192.168.233.3  192.168.233.4      TCP
# 18997            18998  1.328400    192.168.233.4  192.168.233.3      TCP
# 18998            18999  1.328404    192.168.233.3  192.168.233.4      TCP
# 18999            19000  1.328430    192.168.233.4  192.168.233.3      TCP
#
#                  Length                                               Info  \
# (attack, 66070)     174           2915  >  4040 [SYN] Seq=0 Win=64 Len=120
# (attack, 66071)     174           2916  >  4040 [SYN] Seq=0 Win=64 Len=120
# (attack, 66072)     174           2917  >  4040 [SYN] Seq=0 Win=64 Len=120
# (attack, 66073)     174           2918  >  4040 [SYN] Seq=0 Win=64 Len=120
# (attack, 66074)     174           2919  >  4040 [SYN] Seq=0 Win=64 Len=120
# ...                 ...                                                ...
# 18995                66  5201  >  52136 [ACK] Seq=1 Ack=333074950 Win=3...
# 18996             23234  52136  >  5201 [PSH, ACK] Seq=333074950 Ack=1 ...
# 18997                66  5201  >  52136 [ACK] Seq=1 Ack=333098118 Win=3...
# 18998             33370  52136  >  5201 [ACK] Seq=333098118 Ack=1 Win=6...
# 18999                66  5201  >  52136 [ACK] Seq=1 Ack=333131422 Win=3...
#
#                   label  dest port  source port                   protocol  \
# (attack, 66070)  attack       4040         2915  eth:ethertype:ip:tcp:data
# (attack, 66071)  attack       4040         2916  eth:ethertype:ip:tcp:data
# (attack, 66072)  attack       4040         2917  eth:ethertype:ip:tcp:data
# (attack, 66073)  attack       4040         2918  eth:ethertype:ip:tcp:data
# (attack, 66074)  attack       4040         2919  eth:ethertype:ip:tcp:data
# ...                 ...        ...          ...                        ...
# 18995            benign      52136         5201       eth:ethertype:ip:tcp
# 18996            benign       5201        52136  eth:ethertype:ip:tcp:data
# 18997            benign      52136         5201       eth:ethertype:ip:tcp
# 18998            benign       5201        52136  eth:ethertype:ip:tcp:data
# 18999            benign      52136         5201       eth:ethertype:ip:tcp
#
#                  flow duration  Total Fwd Packets  \
# (attack, 66070)       0.000000                NaN
# (attack, 66071)       0.000000                NaN
# (attack, 66072)       0.000000                NaN
# (attack, 66073)       0.000000                NaN
# (attack, 66074)       0.000000                NaN
# ...                        ...                ...
# 18995                 0.000033           0.000033
# 18996                 0.000031                NaN
# 18997                 0.000040           0.000040
# 18998                 0.000004                NaN
# 18999                 0.000027           0.000027
#
#                  Total Length of Bwd Packets  Fwd Packet Length Max  \
# (attack, 66070)                          NaN                    120
# (attack, 66071)                          NaN                    120
# (attack, 66072)                          NaN                    120
# (attack, 66073)                          NaN                    120
# (attack, 66074)                          NaN                    120
# ...                                      ...                    ...
# 18995                                    NaN                      0
# 18996                                    NaN                  23168
# 18997                                    NaN                      0
# 18998                                    NaN                  33304
# 18999                                    NaN                      0
#
#                  Fwd Header Length  Bwd Header Length ACK Flag Count  \
# (attack, 66070)                 20                174        Not set
# (attack, 66071)                 20                174        Not set
# (attack, 66072)                 20                174        Not set
# (attack, 66073)                 20                174        Not set
# (attack, 66074)                 20                174        Not set
# ...                            ...                ...            ...
# 18995                           32                 66            Set
# 18996                           32              23234            Set
# 18997                           32                 66            Set
# 18998                           32              33370            Set
# 18999                           32                 66            Set
#
#                 URG Flag Count  Subflow Bwd Packets
# (attack, 66070)        Not set                  NaN
# (attack, 66071)        Not set                  NaN
# (attack, 66072)        Not set                  NaN
# (attack, 66073)        Not set                  NaN
# (attack, 66074)        Not set                  NaN
# ...                        ...                  ...
# 18995                  Not set             0.000033
# 18996                  Not set                  NaN
# 18997                  Not set             0.000040
# 18998                  Not set                  NaN
# 18999                  Not set             0.000027
#
# [20000 rows x 20 columns]

# %%
# df_1 = df.replace(np.inf, np.nan)
# df_1.isnull().sum().sum()
#sns.heatmap(df_1 == np.nan)
# Out:
# 46091

# %%
# df_2 = df_1.dropna(axis=0)
# df_2.isnull().sum().sum()
# Out:
# Empty DataFrame
# Columns: [No., Time, Source, Destination, Protocol, Length, Info, label, dest port, source port, protocol, flow duration, Total Fwd Packets, Total Length of Bwd Packets, Fwd Packet Length Max, Fwd Header Length, Bwd Header Length, ACK Flag Count, URG Flag Count, Subflow Bwd Packets]
# Index: []

# %%
# df_std = pd.DataFrame(df.std(), columns = ['value'])
# unchange_col = df_std[df_std['value'] == 0].index
# unchange_col
# df_3 = df_2.drop(unchange_col, axis=1)
# df_3
# Out:
# Empty DataFrame
# Columns: [No., Time, Source, Destination, Protocol, Length, Info, label, dest port, source port, protocol, flow duration, Total Fwd Packets, Total Length of Bwd Packets, Fwd Packet Length Max, Fwd Header Length, Bwd Header Length, ACK Flag Count, URG Flag Count, Subflow Bwd Packets]
# Index: []

# %%
df_object = df.select_dtypes(include='object')
df_object.columns
# Out:
# Index(['Source', 'Destination', 'Protocol', 'Info', 'label', 'protocol',
#        'ACK Flag Count', 'URG Flag Count'],
#       dtype='object')

# %%
df_4 = df.drop(['ACK Flag Count', 'URG Flag Count'], axis=1)

# %%
df_4
# Out:
#                    No.      Time           Source    Destination Protocol  \
# (attack, 66070)  66071  8.228322   41.146.181.222  192.168.233.4      TCP
# (attack, 66071)  66072  8.228426  146.243.107.168  192.168.233.4      TCP
# (attack, 66072)  66073  8.233974   192.183.47.127  192.168.233.4      TCP
# (attack, 66073)  66074  8.233975    89.82.221.232  192.168.233.4      TCP
# (attack, 66074)  66075  8.233975    73.76.215.151  192.168.233.4      TCP
# ...                ...       ...              ...            ...      ...
# 18995            18996  1.328329    192.168.233.4  192.168.233.3      TCP
# 18996            18997  1.328360    192.168.233.3  192.168.233.4      TCP
# 18997            18998  1.328400    192.168.233.4  192.168.233.3      TCP
# 18998            18999  1.328404    192.168.233.3  192.168.233.4      TCP
# 18999            19000  1.328430    192.168.233.4  192.168.233.3      TCP
#
#                  Length                                               Info  \
# (attack, 66070)     174           2915  >  4040 [SYN] Seq=0 Win=64 Len=120
# (attack, 66071)     174           2916  >  4040 [SYN] Seq=0 Win=64 Len=120
# (attack, 66072)     174           2917  >  4040 [SYN] Seq=0 Win=64 Len=120
# (attack, 66073)     174           2918  >  4040 [SYN] Seq=0 Win=64 Len=120
# (attack, 66074)     174           2919  >  4040 [SYN] Seq=0 Win=64 Len=120
# ...                 ...                                                ...
# 18995                66  5201  >  52136 [ACK] Seq=1 Ack=333074950 Win=3...
# 18996             23234  52136  >  5201 [PSH, ACK] Seq=333074950 Ack=1 ...
# 18997                66  5201  >  52136 [ACK] Seq=1 Ack=333098118 Win=3...
# 18998             33370  52136  >  5201 [ACK] Seq=333098118 Ack=1 Win=6...
# 18999                66  5201  >  52136 [ACK] Seq=1 Ack=333131422 Win=3...
#
#                   label  dest port  source port                   protocol  \
# (attack, 66070)  attack       4040         2915  eth:ethertype:ip:tcp:data
# (attack, 66071)  attack       4040         2916  eth:ethertype:ip:tcp:data
# (attack, 66072)  attack       4040         2917  eth:ethertype:ip:tcp:data
# (attack, 66073)  attack       4040         2918  eth:ethertype:ip:tcp:data
# (attack, 66074)  attack       4040         2919  eth:ethertype:ip:tcp:data
# ...                 ...        ...          ...                        ...
# 18995            benign      52136         5201       eth:ethertype:ip:tcp
# 18996            benign       5201        52136  eth:ethertype:ip:tcp:data
# 18997            benign      52136         5201       eth:ethertype:ip:tcp
# 18998            benign       5201        52136  eth:ethertype:ip:tcp:data
# 18999            benign      52136         5201       eth:ethertype:ip:tcp
#
#                  flow duration  Total Fwd Packets  \
# (attack, 66070)       0.000000                NaN
# (attack, 66071)       0.000000                NaN
# (attack, 66072)       0.000000                NaN
# (attack, 66073)       0.000000                NaN
# (attack, 66074)       0.000000                NaN
# ...                        ...                ...
# 18995                 0.000033           0.000033
# 18996                 0.000031                NaN
# 18997                 0.000040           0.000040
# 18998                 0.000004                NaN
# 18999                 0.000027           0.000027
#
#                  Total Length of Bwd Packets  Fwd Packet Length Max  \
# (attack, 66070)                          NaN                    120
# (attack, 66071)                          NaN                    120
# (attack, 66072)                          NaN                    120
# (attack, 66073)                          NaN                    120
# (attack, 66074)                          NaN                    120
# ...                                      ...                    ...
# 18995                                    NaN                      0
# 18996                                    NaN                  23168
# 18997                                    NaN                      0
# 18998                                    NaN                  33304
# 18999                                    NaN                      0
#
#                  Fwd Header Length  Bwd Header Length  Subflow Bwd Packets
# (attack, 66070)                 20                174                  NaN
# (attack, 66071)                 20                174                  NaN
# (attack, 66072)                 20                174                  NaN
# (attack, 66073)                 20                174                  NaN
# (attack, 66074)                 20                174                  NaN
# ...                            ...                ...                  ...
# 18995                           32                 66             0.000033
# 18996                           32              23234                  NaN
# 18997                           32                 66             0.000040
# 18998                           32              33370                  NaN
# 18999                           32                 66             0.000027
#
# [20000 rows x 18 columns]

# %%
df_4['Time'].value_counts()
# Out:
# 8.274362    1
# 0.365768    1
# 1.001017    1
# 1.074348    1
# 0.692253    1
#            ..
# 0.873926    1
# 0.484247    1
# 0.651532    1
# 0.245559    1
# 1.270622    1
# Name: Time, Length: 20000, dtype: int64

# %%
df_4.drop(['Time'], axis=1, inplace = True)

# %%
df_4
# Out:
#                    No.           Source    Destination Protocol  Length  \
# (attack, 66070)  66071   41.146.181.222  192.168.233.4      TCP     174
# (attack, 66071)  66072  146.243.107.168  192.168.233.4      TCP     174
# (attack, 66072)  66073   192.183.47.127  192.168.233.4      TCP     174
# (attack, 66073)  66074    89.82.221.232  192.168.233.4      TCP     174
# (attack, 66074)  66075    73.76.215.151  192.168.233.4      TCP     174
# ...                ...              ...            ...      ...     ...
# 18995            18996    192.168.233.4  192.168.233.3      TCP      66
# 18996            18997    192.168.233.3  192.168.233.4      TCP   23234
# 18997            18998    192.168.233.4  192.168.233.3      TCP      66
# 18998            18999    192.168.233.3  192.168.233.4      TCP   33370
# 18999            19000    192.168.233.4  192.168.233.3      TCP      66
#
#                                                               Info   label  \
# (attack, 66070)           2915  >  4040 [SYN] Seq=0 Win=64 Len=120  attack
# (attack, 66071)           2916  >  4040 [SYN] Seq=0 Win=64 Len=120  attack
# (attack, 66072)           2917  >  4040 [SYN] Seq=0 Win=64 Len=120  attack
# (attack, 66073)           2918  >  4040 [SYN] Seq=0 Win=64 Len=120  attack
# (attack, 66074)           2919  >  4040 [SYN] Seq=0 Win=64 Len=120  attack
# ...                                                            ...     ...
# 18995            5201  >  52136 [ACK] Seq=1 Ack=333074950 Win=3...  benign
# 18996            52136  >  5201 [PSH, ACK] Seq=333074950 Ack=1 ...  benign
# 18997            5201  >  52136 [ACK] Seq=1 Ack=333098118 Win=3...  benign
# 18998            52136  >  5201 [ACK] Seq=333098118 Ack=1 Win=6...  benign
# 18999            5201  >  52136 [ACK] Seq=1 Ack=333131422 Win=3...  benign
#
#                  dest port  source port                   protocol  \
# (attack, 66070)       4040         2915  eth:ethertype:ip:tcp:data
# (attack, 66071)       4040         2916  eth:ethertype:ip:tcp:data
# (attack, 66072)       4040         2917  eth:ethertype:ip:tcp:data
# (attack, 66073)       4040         2918  eth:ethertype:ip:tcp:data
# (attack, 66074)       4040         2919  eth:ethertype:ip:tcp:data
# ...                    ...          ...                        ...
# 18995                52136         5201       eth:ethertype:ip:tcp
# 18996                 5201        52136  eth:ethertype:ip:tcp:data
# 18997                52136         5201       eth:ethertype:ip:tcp
# 18998                 5201        52136  eth:ethertype:ip:tcp:data
# 18999                52136         5201       eth:ethertype:ip:tcp
#
#                  flow duration  Total Fwd Packets  \
# (attack, 66070)       0.000000                NaN
# (attack, 66071)       0.000000                NaN
# (attack, 66072)       0.000000                NaN
# (attack, 66073)       0.000000                NaN
# (attack, 66074)       0.000000                NaN
# ...                        ...                ...
# 18995                 0.000033           0.000033
# 18996                 0.000031                NaN
# 18997                 0.000040           0.000040
# 18998                 0.000004                NaN
# 18999                 0.000027           0.000027
#
#                  Total Length of Bwd Packets  Fwd Packet Length Max  \
# (attack, 66070)                          NaN                    120
# (attack, 66071)                          NaN                    120
# (attack, 66072)                          NaN                    120
# (attack, 66073)                          NaN                    120
# (attack, 66074)                          NaN                    120
# ...                                      ...                    ...
# 18995                                    NaN                      0
# 18996                                    NaN                  23168
# 18997                                    NaN                      0
# 18998                                    NaN                  33304
# 18999                                    NaN                      0
#
#                  Fwd Header Length  Bwd Header Length  Subflow Bwd Packets
# (attack, 66070)                 20                174                  NaN
# (attack, 66071)                 20                174                  NaN
# (attack, 66072)                 20                174                  NaN
# (attack, 66073)                 20                174                  NaN
# (attack, 66074)                 20                174                  NaN
# ...                            ...                ...                  ...
# 18995                           32                 66             0.000033
# 18996                           32              23234                  NaN
# 18997                           32                 66             0.000040
# 18998                           32              33370                  NaN
# 18999                           32                 66             0.000027
#
# [20000 rows x 17 columns]

# %%
df_4['Total Length of Bwd Packets'].value_counts()
# Out:
# Series([], Name: Total Length of Bwd Packets, dtype: int64)

# %%
df_4.drop(['Total Length of Bwd Packets'], axis=1, inplace = True)

# %%
df_4
# Out:
#                    No.           Source    Destination Protocol  Length  \
# (attack, 66070)  66071   41.146.181.222  192.168.233.4      TCP     174
# (attack, 66071)  66072  146.243.107.168  192.168.233.4      TCP     174
# (attack, 66072)  66073   192.183.47.127  192.168.233.4      TCP     174
# (attack, 66073)  66074    89.82.221.232  192.168.233.4      TCP     174
# (attack, 66074)  66075    73.76.215.151  192.168.233.4      TCP     174
# ...                ...              ...            ...      ...     ...
# 18995            18996    192.168.233.4  192.168.233.3      TCP      66
# 18996            18997    192.168.233.3  192.168.233.4      TCP   23234
# 18997            18998    192.168.233.4  192.168.233.3      TCP      66
# 18998            18999    192.168.233.3  192.168.233.4      TCP   33370
# 18999            19000    192.168.233.4  192.168.233.3      TCP      66
#
#                                                               Info   label  \
# (attack, 66070)           2915  >  4040 [SYN] Seq=0 Win=64 Len=120  attack
# (attack, 66071)           2916  >  4040 [SYN] Seq=0 Win=64 Len=120  attack
# (attack, 66072)           2917  >  4040 [SYN] Seq=0 Win=64 Len=120  attack
# (attack, 66073)           2918  >  4040 [SYN] Seq=0 Win=64 Len=120  attack
# (attack, 66074)           2919  >  4040 [SYN] Seq=0 Win=64 Len=120  attack
# ...                                                            ...     ...
# 18995            5201  >  52136 [ACK] Seq=1 Ack=333074950 Win=3...  benign
# 18996            52136  >  5201 [PSH, ACK] Seq=333074950 Ack=1 ...  benign
# 18997            5201  >  52136 [ACK] Seq=1 Ack=333098118 Win=3...  benign
# 18998            52136  >  5201 [ACK] Seq=333098118 Ack=1 Win=6...  benign
# 18999            5201  >  52136 [ACK] Seq=1 Ack=333131422 Win=3...  benign
#
#                  dest port  source port                   protocol  \
# (attack, 66070)       4040         2915  eth:ethertype:ip:tcp:data
# (attack, 66071)       4040         2916  eth:ethertype:ip:tcp:data
# (attack, 66072)       4040         2917  eth:ethertype:ip:tcp:data
# (attack, 66073)       4040         2918  eth:ethertype:ip:tcp:data
# (attack, 66074)       4040         2919  eth:ethertype:ip:tcp:data
# ...                    ...          ...                        ...
# 18995                52136         5201       eth:ethertype:ip:tcp
# 18996                 5201        52136  eth:ethertype:ip:tcp:data
# 18997                52136         5201       eth:ethertype:ip:tcp
# 18998                 5201        52136  eth:ethertype:ip:tcp:data
# 18999                52136         5201       eth:ethertype:ip:tcp
#
#                  flow duration  Total Fwd Packets  Fwd Packet Length Max  \
# (attack, 66070)       0.000000                NaN                    120
# (attack, 66071)       0.000000                NaN                    120
# (attack, 66072)       0.000000                NaN                    120
# (attack, 66073)       0.000000                NaN                    120
# (attack, 66074)       0.000000                NaN                    120
# ...                        ...                ...                    ...
# 18995                 0.000033           0.000033                      0
# 18996                 0.000031                NaN                  23168
# 18997                 0.000040           0.000040                      0
# 18998                 0.000004                NaN                  33304
# 18999                 0.000027           0.000027                      0
#
#                  Fwd Header Length  Bwd Header Length  Subflow Bwd Packets
# (attack, 66070)                 20                174                  NaN
# (attack, 66071)                 20                174                  NaN
# (attack, 66072)                 20                174                  NaN
# (attack, 66073)                 20                174                  NaN
# (attack, 66074)                 20                174                  NaN
# ...                            ...                ...                  ...
# 18995                           32                 66             0.000033
# 18996                           32              23234                  NaN
# 18997                           32                 66             0.000040
# 18998                           32              33370                  NaN
# 18999                           32                 66             0.000027
#
# [20000 rows x 16 columns]

# %%
df_corr = df_4.corr().abs()
corr_val = df_corr.values
corr_val[1][1] = 1
mask = np.zeros_like(corr_val)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(7, 7))
    ax = sns.heatmap(corr_val, mask=mask, vmax=0.9, square=True)

# %%
high_corr = df_corr.where(np.triu(np.ones(df_corr.shape),k=1).astype(np.bool))
# Out:
# <ipython-input-152-266b65e27521>:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   high_corr = df_corr.where(np.triu(np.ones(df_corr.shape),k=1).astype(np.bool))

# %%
to_drop = [column for column in high_corr.columns if any(high_corr[column] > 0.90)]
to_drop
# Out:
# ['Total Fwd Packets',
#  'Fwd Packet Length Max',
#  'Bwd Header Length',
#  'Subflow Bwd Packets']

# %%
df_5 = df_4.drop(to_drop, axis=1)
df_5
# Out:
#                    No.           Source    Destination Protocol  Length  \
# (attack, 66070)  66071   41.146.181.222  192.168.233.4      TCP     174
# (attack, 66071)  66072  146.243.107.168  192.168.233.4      TCP     174
# (attack, 66072)  66073   192.183.47.127  192.168.233.4      TCP     174
# (attack, 66073)  66074    89.82.221.232  192.168.233.4      TCP     174
# (attack, 66074)  66075    73.76.215.151  192.168.233.4      TCP     174
# ...                ...              ...            ...      ...     ...
# 18995            18996    192.168.233.4  192.168.233.3      TCP      66
# 18996            18997    192.168.233.3  192.168.233.4      TCP   23234
# 18997            18998    192.168.233.4  192.168.233.3      TCP      66
# 18998            18999    192.168.233.3  192.168.233.4      TCP   33370
# 18999            19000    192.168.233.4  192.168.233.3      TCP      66
#
#                                                               Info   label  \
# (attack, 66070)           2915  >  4040 [SYN] Seq=0 Win=64 Len=120  attack
# (attack, 66071)           2916  >  4040 [SYN] Seq=0 Win=64 Len=120  attack
# (attack, 66072)           2917  >  4040 [SYN] Seq=0 Win=64 Len=120  attack
# (attack, 66073)           2918  >  4040 [SYN] Seq=0 Win=64 Len=120  attack
# (attack, 66074)           2919  >  4040 [SYN] Seq=0 Win=64 Len=120  attack
# ...                                                            ...     ...
# 18995            5201  >  52136 [ACK] Seq=1 Ack=333074950 Win=3...  benign
# 18996            52136  >  5201 [PSH, ACK] Seq=333074950 Ack=1 ...  benign
# 18997            5201  >  52136 [ACK] Seq=1 Ack=333098118 Win=3...  benign
# 18998            52136  >  5201 [ACK] Seq=333098118 Ack=1 Win=6...  benign
# 18999            5201  >  52136 [ACK] Seq=1 Ack=333131422 Win=3...  benign
#
#                  dest port  source port                   protocol  \
# (attack, 66070)       4040         2915  eth:ethertype:ip:tcp:data
# (attack, 66071)       4040         2916  eth:ethertype:ip:tcp:data
# (attack, 66072)       4040         2917  eth:ethertype:ip:tcp:data
# (attack, 66073)       4040         2918  eth:ethertype:ip:tcp:data
# (attack, 66074)       4040         2919  eth:ethertype:ip:tcp:data
# ...                    ...          ...                        ...
# 18995                52136         5201       eth:ethertype:ip:tcp
# 18996                 5201        52136  eth:ethertype:ip:tcp:data
# 18997                52136         5201       eth:ethertype:ip:tcp
# 18998                 5201        52136  eth:ethertype:ip:tcp:data
# 18999                52136         5201       eth:ethertype:ip:tcp
#
#                  flow duration  Fwd Header Length
# (attack, 66070)       0.000000                 20
# (attack, 66071)       0.000000                 20
# (attack, 66072)       0.000000                 20
# (attack, 66073)       0.000000                 20
# (attack, 66074)       0.000000                 20
# ...                        ...                ...
# 18995                 0.000033                 32
# 18996                 0.000031                 32
# 18997                 0.000040                 32
# 18998                 0.000004                 32
# 18999                 0.000027                 32
#
# [20000 rows x 12 columns]

# %%
df_corr = df_5.corr().abs()
corr_val = df_corr.values
corr_val[1][1] = 1
mask = np.zeros_like(corr_val)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(7, 7))
    ax = sns.heatmap(corr_val, mask=mask, vmax=0.9, square=True)

# %%
df_corr.loc[1, 1] = 1

# %%
# df_5 = df_4.reset_index()
# df_5 = df_5.drop(['No.'], axis = 1)
# df_5 = df_5.sample(frac = 1)
# sns.heatmap(df_5 == -1)
# Out:
# <AxesSubplot:>

# %%
# negative_df = df_5 == -1
# number_of_negative_df = pd.DataFrame(negative_df.sum(), columns = ['count']).reset_index()
# df_size = len(df_5)
# to_drop = number_of_negative_df[number_of_negative_df['count'] > 1]['index'].values
# to_drop
# Out:
# array([], dtype=object)

# %%
df_6 = df_5.reset_index()
df_6 = df_6.drop(['index'], axis = 1)
df_6 = df_6.sample(frac = 1)

# %%
sns.heatmap(df_6 == 0)
# Out:
# <AxesSubplot:>

# %%
# zero_df = df_6 == 0
# number_of_zero_df = pd.DataFrame(zero_df.sum(), columns = ['count']).reset_index()
# df_size = len(df_6)
# to_drop = number_of_zero_df[number_of_zero_df['count'] > (df_size * 0.85)]['index']
# to_drop
# Out:
# Series([], Name: index, dtype: object)

# %%
# df_7 = df_6.drop(to_drop, axis = 1)

# %%
df_8 = df_6.copy()
df_8
# Out:
#        level_0         Source    Destination Protocol  Length  \
# 18897     8593  192.168.233.3  192.168.233.4      TCP   33370
# 19081    11182  192.168.233.4  192.168.233.3      TCP      66
# 1666      5751  192.168.233.4  192.168.233.3      TCP      66
# 5509      6959  192.168.233.4  192.168.233.3      TCP      66
# 15782     4272  192.168.233.4  192.168.233.3      TCP      66
# ...        ...            ...            ...      ...     ...
# 4316      6903  192.168.233.3  192.168.233.4      TCP   31922
# 6268     17852  192.168.233.4  192.168.233.3      TCP      66
# 8774      2998  192.168.233.4  192.168.233.3      TCP      66
# 13083    16028  192.168.233.3  192.168.233.4      TCP   49298
# 6491     16082  192.168.233.4  192.168.233.3      TCP      66
#
#                                                     Info   label  dest port  \
# 18897  52136  >  5201 [PSH, ACK] Seq=140321534 Ack=1 ...  benign       5201
# 19081  5201  >  52136 [ACK] Seq=1 Ack=186039238 Win=3...  benign      52136
# 1666   5201  >  52136 [ACK] Seq=1 Ack=93178998 Win=31...  benign      52136
# 5509   5201  >  52136 [ACK] Seq=1 Ack=114777366 Win=3...  benign      52136
# 15782  5201  >  52136 [ACK] Seq=1 Ack=71328678 Win=31...  benign      52136
# ...                                                  ...     ...        ...
# 4316   52136  >  5201 [PSH, ACK] Seq=113965038 Ack=1 ...  benign       5201
# 6268   5201  >  52136 [ACK] Seq=1 Ack=296934318 Win=3...  benign      52136
# 8774   5201  >  52136 [ACK] Seq=1 Ack=41750382 Win=31...  benign      52136
# 13083  52136  >  5201 [ACK] Seq=267677478 Ack=1 Win=6...  benign       5201
# 6491   5201  >  52136 [ACK] Seq=1 Ack=268550622 Win=3...  benign      52136
#
#        source port                   protocol  flow duration  \
# 18897        52136  eth:ethertype:ip:tcp:data       0.004064
# 19081         5201       eth:ethertype:ip:tcp       0.000014
# 1666          5201       eth:ethertype:ip:tcp       0.000037
# 5509          5201       eth:ethertype:ip:tcp       0.000046
# 15782         5201       eth:ethertype:ip:tcp       0.000018
# ...            ...                        ...            ...
# 4316         52136  eth:ethertype:ip:tcp:data       0.000022
# 6268          5201       eth:ethertype:ip:tcp       0.000016
# 8774          5201       eth:ethertype:ip:tcp       0.000019
# 13083        52136  eth:ethertype:ip:tcp:data       0.000003
# 6491          5201       eth:ethertype:ip:tcp       0.000043
#
#        Total Fwd Packets  Fwd Packet Length Max  Fwd Header Length  \
# 18897                NaN                  33304                 32
# 19081           0.000016                      0                 32
# 1666            0.000037                      0                 32
# 5509            0.000046                      0                 32
# 15782           0.000018                      0                 32
# ...                  ...                    ...                ...
# 4316                 NaN                  31856                 32
# 6268            0.000016                      0                 32
# 8774            0.000019                      0                 32
# 13083                NaN                  49232                 32
# 6491            0.000043                      0                 32
#
#        Bwd Header Length  Subflow Bwd Packets
# 18897              33370                  NaN
# 19081                 66             0.000016
# 1666                  66             0.000037
# 5509                  66             0.000046
# 15782                 66             0.000018
# ...                  ...                  ...
# 4316               31922                  NaN
# 6268                  66             0.000016
# 8774                  66             0.000019
# 13083              49298                  NaN
# 6491                  66             0.000043
#
# [20000 rows x 16 columns]

# %%
df_9 = df_8.sample(frac = 1)
df_9
# Out:
#        level_0         Source    Destination Protocol  Length  \
# 15247    16013  192.168.233.3  192.168.233.4      TCP   43506
# 9525     12743  192.168.233.4  192.168.233.3      TCP      66
# 7468      9020  192.168.233.3  192.168.233.4      TCP   14546
# 9196      7816  192.168.233.4  192.168.233.3      TCP      66
# 8264     16302  192.168.233.3  192.168.233.4      TCP   36266
# ...        ...            ...            ...      ...     ...
# 3341     17149  192.168.233.3  192.168.233.4      TCP   40610
# 18250     7689  192.168.233.3  192.168.233.4      TCP   37714
# 18896     7831  192.168.233.4  192.168.233.3      TCP      66
# 5378      2104  192.168.233.3  192.168.233.4      TCP    5858
# 9643      4669  192.168.233.4  192.168.233.3      TCP      66
#
#                                                     Info   label  dest port  \
# 15247  52136  >  5201 [PSH, ACK] Seq=267481998 Ack=1 ...  benign       5201
# 9525   5201  >  52136 [ACK] Seq=1 Ack=213724998 Win=3...  benign      52136
# 7468   52136  >  5201 [PSH, ACK] Seq=147958286 Ack=1 ...  benign       5201
# 9196   5201  >  52136 [ACK] Seq=1 Ack=129775750 Win=3...  benign      52136
# 8264   52136  >  5201 [PSH, ACK] Seq=271290238 Ack=1 ...  benign       5201
# ...                                                  ...     ...        ...
# 3341   52136  >  5201 [ACK] Seq=285479190 Ack=1 Win=6...  benign       5201
# 18250  52136  >  5201 [ACK] Seq=127648638 Ack=1 Win=6...  benign       5201
# 18896  5201  >  52136 [ACK] Seq=1 Ack=129992950 Win=3...  benign      52136
# 5378   52136  >  5201 [PSH, ACK] Seq=25857134 Ack=1 W...  benign       5201
# 9643   5201  >  52136 [ACK] Seq=1 Ack=77437790 Win=31...  benign      52136
#
#        source port                   protocol  flow duration  \
# 15247        52136  eth:ethertype:ip:tcp:data       0.000020
# 9525          5201       eth:ethertype:ip:tcp       0.000037
# 7468         52136  eth:ethertype:ip:tcp:data       0.000020
# 9196          5201       eth:ethertype:ip:tcp       0.000015
# 8264         52136  eth:ethertype:ip:tcp:data       0.001881
# ...            ...                        ...            ...
# 3341         52136  eth:ethertype:ip:tcp:data       0.000017
# 18250        52136  eth:ethertype:ip:tcp:data       0.000019
# 18896         5201       eth:ethertype:ip:tcp       0.000036
# 5378         52136  eth:ethertype:ip:tcp:data       0.000010
# 9643          5201       eth:ethertype:ip:tcp       0.000025
#
#        Total Fwd Packets  Fwd Packet Length Max  Fwd Header Length  \
# 15247                NaN                  43440                 32
# 9525            0.000037                      0                 32
# 7468                 NaN                  14480                 32
# 9196            0.000015                      0                 32
# 8264                 NaN                  36200                 32
# ...                  ...                    ...                ...
# 3341                 NaN                  40544                 32
# 18250                NaN                  37648                 32
# 18896           0.000036                      0                 32
# 5378                 NaN                   5792                 32
# 9643            0.000031                      0                 32
#
#        Bwd Header Length  Subflow Bwd Packets
# 15247              43506                  NaN
# 9525                  66             0.000037
# 7468               14546                  NaN
# 9196                  66             0.000015
# 8264               36266                  NaN
# ...                  ...                  ...
# 3341               40610                  NaN
# 18250              37714                  NaN
# 18896                 66             0.000036
# 5378                5858                  NaN
# 9643                  66             0.000031
#
# [20000 rows x 16 columns]

# %%
sns.heatmap(df_9 == 0)
# Out:
# <AxesSubplot:>

# %%
df_9
# Out:
#        level_0         Source    Destination Protocol  Length  \
# 15247    16013  192.168.233.3  192.168.233.4      TCP   43506
# 9525     12743  192.168.233.4  192.168.233.3      TCP      66
# 7468      9020  192.168.233.3  192.168.233.4      TCP   14546
# 9196      7816  192.168.233.4  192.168.233.3      TCP      66
# 8264     16302  192.168.233.3  192.168.233.4      TCP   36266
# ...        ...            ...            ...      ...     ...
# 3341     17149  192.168.233.3  192.168.233.4      TCP   40610
# 18250     7689  192.168.233.3  192.168.233.4      TCP   37714
# 18896     7831  192.168.233.4  192.168.233.3      TCP      66
# 5378      2104  192.168.233.3  192.168.233.4      TCP    5858
# 9643      4669  192.168.233.4  192.168.233.3      TCP      66
#
#                                                     Info   label  dest port  \
# 15247  52136  >  5201 [PSH, ACK] Seq=267481998 Ack=1 ...  benign       5201
# 9525   5201  >  52136 [ACK] Seq=1 Ack=213724998 Win=3...  benign      52136
# 7468   52136  >  5201 [PSH, ACK] Seq=147958286 Ack=1 ...  benign       5201
# 9196   5201  >  52136 [ACK] Seq=1 Ack=129775750 Win=3...  benign      52136
# 8264   52136  >  5201 [PSH, ACK] Seq=271290238 Ack=1 ...  benign       5201
# ...                                                  ...     ...        ...
# 3341   52136  >  5201 [ACK] Seq=285479190 Ack=1 Win=6...  benign       5201
# 18250  52136  >  5201 [ACK] Seq=127648638 Ack=1 Win=6...  benign       5201
# 18896  5201  >  52136 [ACK] Seq=1 Ack=129992950 Win=3...  benign      52136
# 5378   52136  >  5201 [PSH, ACK] Seq=25857134 Ack=1 W...  benign       5201
# 9643   5201  >  52136 [ACK] Seq=1 Ack=77437790 Win=31...  benign      52136
#
#        source port                   protocol  flow duration  \
# 15247        52136  eth:ethertype:ip:tcp:data       0.000020
# 9525          5201       eth:ethertype:ip:tcp       0.000037
# 7468         52136  eth:ethertype:ip:tcp:data       0.000020
# 9196          5201       eth:ethertype:ip:tcp       0.000015
# 8264         52136  eth:ethertype:ip:tcp:data       0.001881
# ...            ...                        ...            ...
# 3341         52136  eth:ethertype:ip:tcp:data       0.000017
# 18250        52136  eth:ethertype:ip:tcp:data       0.000019
# 18896         5201       eth:ethertype:ip:tcp       0.000036
# 5378         52136  eth:ethertype:ip:tcp:data       0.000010
# 9643          5201       eth:ethertype:ip:tcp       0.000025
#
#        Total Fwd Packets  Fwd Packet Length Max  Fwd Header Length  \
# 15247                NaN                  43440                 32
# 9525            0.000037                      0                 32
# 7468                 NaN                  14480                 32
# 9196            0.000015                      0                 32
# 8264                 NaN                  36200                 32
# ...                  ...                    ...                ...
# 3341                 NaN                  40544                 32
# 18250                NaN                  37648                 32
# 18896           0.000036                      0                 32
# 5378                 NaN                   5792                 32
# 9643            0.000031                      0                 32
#
#        Bwd Header Length  Subflow Bwd Packets
# 15247              43506                  NaN
# 9525                  66             0.000037
# 7468               14546                  NaN
# 9196                  66             0.000015
# 8264               36266                  NaN
# ...                  ...                  ...
# 3341               40610                  NaN
# 18250              37714                  NaN
# 18896                 66             0.000036
# 5378                5858                  NaN
# 9643                  66             0.000031
#
# [20000 rows x 16 columns]

# %%
destination_port_df = pd.DataFrame(df_9['dest port'].value_counts())
dp_df_size = len(destination_port_df)
unmost_port = destination_port_df.tail(dp_df_size - 10).index
df_11 = df_9.copy()
df_11 = df_9.replace(to_replace = unmost_port, value =99999)
df_11 = pd.get_dummies(df_11, columns = ['dest port'])
df_11
# Out:
#        level_0         Source    Destination Protocol  Length  \
# 15247    16013  192.168.233.3  192.168.233.4      TCP   43506
# 9525     12743  192.168.233.4  192.168.233.3      TCP      66
# 7468      9020  192.168.233.3  192.168.233.4      TCP   14546
# 9196      7816  192.168.233.4  192.168.233.3      TCP      66
# 8264     16302  192.168.233.3  192.168.233.4      TCP   36266
# ...        ...            ...            ...      ...     ...
# 3341     17149  192.168.233.3  192.168.233.4      TCP   40610
# 18250     7689  192.168.233.3  192.168.233.4      TCP   37714
# 18896     7831  192.168.233.4  192.168.233.3      TCP      66
# 5378      2104  192.168.233.3  192.168.233.4      TCP    5858
# 9643      4669  192.168.233.4  192.168.233.3      TCP      66
#
#                                                     Info   label  source port  \
# 15247  52136  >  5201 [PSH, ACK] Seq=267481998 Ack=1 ...  benign        52136
# 9525   5201  >  52136 [ACK] Seq=1 Ack=213724998 Win=3...  benign         5201
# 7468   52136  >  5201 [PSH, ACK] Seq=147958286 Ack=1 ...  benign        52136
# 9196   5201  >  52136 [ACK] Seq=1 Ack=129775750 Win=3...  benign         5201
# 8264   52136  >  5201 [PSH, ACK] Seq=271290238 Ack=1 ...  benign        52136
# ...                                                  ...     ...          ...
# 3341   52136  >  5201 [ACK] Seq=285479190 Ack=1 Win=6...  benign        52136
# 18250  52136  >  5201 [ACK] Seq=127648638 Ack=1 Win=6...  benign        52136
# 18896  5201  >  52136 [ACK] Seq=1 Ack=129992950 Win=3...  benign         5201
# 5378   52136  >  5201 [PSH, ACK] Seq=25857134 Ack=1 W...  benign        52136
# 9643   5201  >  52136 [ACK] Seq=1 Ack=77437790 Win=31...  benign         5201
#
#                         protocol  flow duration  Total Fwd Packets  \
# 15247  eth:ethertype:ip:tcp:data       0.000020                NaN
# 9525        eth:ethertype:ip:tcp       0.000037           0.000037
# 7468   eth:ethertype:ip:tcp:data       0.000020                NaN
# 9196        eth:ethertype:ip:tcp       0.000015           0.000015
# 8264   eth:ethertype:ip:tcp:data       0.001881                NaN
# ...                          ...            ...                ...
# 3341   eth:ethertype:ip:tcp:data       0.000017                NaN
# 18250  eth:ethertype:ip:tcp:data       0.000019                NaN
# 18896       eth:ethertype:ip:tcp       0.000036           0.000036
# 5378   eth:ethertype:ip:tcp:data       0.000010                NaN
# 9643        eth:ethertype:ip:tcp       0.000025           0.000031
#
#        Fwd Packet Length Max  Fwd Header Length  Bwd Header Length  \
# 15247                  43440                 32              43506
# 9525                       0                 32                 66
# 7468                   14480                 32              14546
# 9196                       0                 32                 66
# 8264                   36200                 32              36266
# ...                      ...                ...                ...
# 3341                   40544                 32              40610
# 18250                  37648                 32              37714
# 18896                      0                 32                 66
# 5378                    5792                 32               5858
# 9643                       0                 32                 66
#
#        Subflow Bwd Packets  dest port_4040  dest port_5201  dest port_52120  \
# 15247                  NaN               0               1                0
# 9525              0.000037               0               0                0
# 7468                   NaN               0               1                0
# 9196              0.000015               0               0                0
# 8264                   NaN               0               1                0
# ...                    ...             ...             ...              ...
# 3341                   NaN               0               1                0
# 18250                  NaN               0               1                0
# 18896             0.000036               0               0                0
# 5378                   NaN               0               1                0
# 9643              0.000031               0               0                0
#
#        dest port_52136
# 15247                0
# 9525                 1
# 7468                 0
# 9196                 1
# 8264                 0
# ...                ...
# 3341                 0
# 18250                0
# 18896                1
# 5378                 0
# 9643                 1
#
# [20000 rows x 19 columns]

# %%
Source_Port_df = pd.DataFrame(df_11['source port'].value_counts())
sp_df_size = len(Source_Port_df)
unmost_port = Source_Port_df.tail(sp_df_size - 10).index
df_12 = df_11.copy()
df_12['source port'] = df_11['source port'].replace(to_replace = unmost_port, value =99999)
df_12 = pd.get_dummies(df_12, columns = ['source port'])
df_12
# Out:
#        level_0         Source    Destination Protocol  Length  \
# 15247    16013  192.168.233.3  192.168.233.4      TCP   43506
# 9525     12743  192.168.233.4  192.168.233.3      TCP      66
# 7468      9020  192.168.233.3  192.168.233.4      TCP   14546
# 9196      7816  192.168.233.4  192.168.233.3      TCP      66
# 8264     16302  192.168.233.3  192.168.233.4      TCP   36266
# ...        ...            ...            ...      ...     ...
# 3341     17149  192.168.233.3  192.168.233.4      TCP   40610
# 18250     7689  192.168.233.3  192.168.233.4      TCP   37714
# 18896     7831  192.168.233.4  192.168.233.3      TCP      66
# 5378      2104  192.168.233.3  192.168.233.4      TCP    5858
# 9643      4669  192.168.233.4  192.168.233.3      TCP      66
#
#                                                     Info   label  \
# 15247  52136  >  5201 [PSH, ACK] Seq=267481998 Ack=1 ...  benign
# 9525   5201  >  52136 [ACK] Seq=1 Ack=213724998 Win=3...  benign
# 7468   52136  >  5201 [PSH, ACK] Seq=147958286 Ack=1 ...  benign
# 9196   5201  >  52136 [ACK] Seq=1 Ack=129775750 Win=3...  benign
# 8264   52136  >  5201 [PSH, ACK] Seq=271290238 Ack=1 ...  benign
# ...                                                  ...     ...
# 3341   52136  >  5201 [ACK] Seq=285479190 Ack=1 Win=6...  benign
# 18250  52136  >  5201 [ACK] Seq=127648638 Ack=1 Win=6...  benign
# 18896  5201  >  52136 [ACK] Seq=1 Ack=129992950 Win=3...  benign
# 5378   52136  >  5201 [PSH, ACK] Seq=25857134 Ack=1 W...  benign
# 9643   5201  >  52136 [ACK] Seq=1 Ack=77437790 Win=31...  benign
#
#                         protocol  flow duration  Total Fwd Packets  ...  \
# 15247  eth:ethertype:ip:tcp:data       0.000020                NaN  ...
# 9525        eth:ethertype:ip:tcp       0.000037           0.000037  ...
# 7468   eth:ethertype:ip:tcp:data       0.000020                NaN  ...
# 9196        eth:ethertype:ip:tcp       0.000015           0.000015  ...
# 8264   eth:ethertype:ip:tcp:data       0.001881                NaN  ...
# ...                          ...            ...                ...  ...
# 3341   eth:ethertype:ip:tcp:data       0.000017                NaN  ...
# 18250  eth:ethertype:ip:tcp:data       0.000019                NaN  ...
# 18896       eth:ethertype:ip:tcp       0.000036           0.000036  ...
# 5378   eth:ethertype:ip:tcp:data       0.000010                NaN  ...
# 9643        eth:ethertype:ip:tcp       0.000025           0.000031  ...
#
#        source port_3547  source port_3563  source port_3579  source port_3595  \
# 15247                 0                 0                 0                 0
# 9525                  0                 0                 0                 0
# 7468                  0                 0                 0                 0
# 9196                  0                 0                 0                 0
# 8264                  0                 0                 0                 0
# ...                 ...               ...               ...               ...
# 3341                  0                 0                 0                 0
# 18250                 0                 0                 0                 0
# 18896                 0                 0                 0                 0
# 5378                  0                 0                 0                 0
# 9643                  0                 0                 0                 0
#
#        source port_3611  source port_3627  source port_5201  \
# 15247                 0                 0                 0
# 9525                  0                 0                 1
# 7468                  0                 0                 0
# 9196                  0                 0                 1
# 8264                  0                 0                 0
# ...                 ...               ...               ...
# 3341                  0                 0                 0
# 18250                 0                 0                 0
# 18896                 0                 0                 1
# 5378                  0                 0                 0
# 9643                  0                 0                 1
#
#        source port_52120  source port_52136  source port_99999
# 15247                  0                  1                  0
# 9525                   0                  0                  0
# 7468                   0                  1                  0
# 9196                   0                  0                  0
# 8264                   0                  1                  0
# ...                  ...                ...                ...
# 3341                   0                  1                  0
# 18250                  0                  1                  0
# 18896                  0                  0                  0
# 5378                   0                  1                  0
# 9643                   0                  0                  0
#
# [20000 rows x 29 columns]

# %%
# df_12_encoded = pd.get_dummies(df_12, columns=['Source', 'Destination'])
# df_12_encoded
df_12_dropped = df_12.drop(['Source', 'Destination'], axis=1)
df_12_dropped
# Out:
#        level_0 Protocol  Length  \
# 15247    16013      TCP   43506
# 9525     12743      TCP      66
# 7468      9020      TCP   14546
# 9196      7816      TCP      66
# 8264     16302      TCP   36266
# ...        ...      ...     ...
# 3341     17149      TCP   40610
# 18250     7689      TCP   37714
# 18896     7831      TCP      66
# 5378      2104      TCP    5858
# 9643      4669      TCP      66
#
#                                                     Info   label  \
# 15247  52136  >  5201 [PSH, ACK] Seq=267481998 Ack=1 ...  benign
# 9525   5201  >  52136 [ACK] Seq=1 Ack=213724998 Win=3...  benign
# 7468   52136  >  5201 [PSH, ACK] Seq=147958286 Ack=1 ...  benign
# 9196   5201  >  52136 [ACK] Seq=1 Ack=129775750 Win=3...  benign
# 8264   52136  >  5201 [PSH, ACK] Seq=271290238 Ack=1 ...  benign
# ...                                                  ...     ...
# 3341   52136  >  5201 [ACK] Seq=285479190 Ack=1 Win=6...  benign
# 18250  52136  >  5201 [ACK] Seq=127648638 Ack=1 Win=6...  benign
# 18896  5201  >  52136 [ACK] Seq=1 Ack=129992950 Win=3...  benign
# 5378   52136  >  5201 [PSH, ACK] Seq=25857134 Ack=1 W...  benign
# 9643   5201  >  52136 [ACK] Seq=1 Ack=77437790 Win=31...  benign
#
#                         protocol  flow duration  Total Fwd Packets  \
# 15247  eth:ethertype:ip:tcp:data       0.000020                NaN
# 9525        eth:ethertype:ip:tcp       0.000037           0.000037
# 7468   eth:ethertype:ip:tcp:data       0.000020                NaN
# 9196        eth:ethertype:ip:tcp       0.000015           0.000015
# 8264   eth:ethertype:ip:tcp:data       0.001881                NaN
# ...                          ...            ...                ...
# 3341   eth:ethertype:ip:tcp:data       0.000017                NaN
# 18250  eth:ethertype:ip:tcp:data       0.000019                NaN
# 18896       eth:ethertype:ip:tcp       0.000036           0.000036
# 5378   eth:ethertype:ip:tcp:data       0.000010                NaN
# 9643        eth:ethertype:ip:tcp       0.000025           0.000031
#
#        Fwd Packet Length Max  Fwd Header Length  ...  source port_3547  \
# 15247                  43440                 32  ...                 0
# 9525                       0                 32  ...                 0
# 7468                   14480                 32  ...                 0
# 9196                       0                 32  ...                 0
# 8264                   36200                 32  ...                 0
# ...                      ...                ...  ...               ...
# 3341                   40544                 32  ...                 0
# 18250                  37648                 32  ...                 0
# 18896                      0                 32  ...                 0
# 5378                    5792                 32  ...                 0
# 9643                       0                 32  ...                 0
#
#        source port_3563  source port_3579  source port_3595  source port_3611  \
# 15247                 0                 0                 0                 0
# 9525                  0                 0                 0                 0
# 7468                  0                 0                 0                 0
# 9196                  0                 0                 0                 0
# 8264                  0                 0                 0                 0
# ...                 ...               ...               ...               ...
# 3341                  0                 0                 0                 0
# 18250                 0                 0                 0                 0
# 18896                 0                 0                 0                 0
# 5378                  0                 0                 0                 0
# 9643                  0                 0                 0                 0
#
#        source port_3627  source port_5201  source port_52120  \
# 15247                 0                 0                  0
# 9525                  0                 1                  0
# 7468                  0                 0                  0
# 9196                  0                 1                  0
# 8264                  0                 0                  0
# ...                 ...               ...                ...
# 3341                  0                 0                  0
# 18250                 0                 0                  0
# 18896                 0                 1                  0
# 5378                  0                 0                  0
# 9643                  0                 1                  0
#
#        source port_52136  source port_99999
# 15247                  1                  0
# 9525                   0                  0
# 7468                   1                  0
# 9196                   0                  0
# 8264                   1                  0
# ...                  ...                ...
# 3341                   1                  0
# 18250                  1                  0
# 18896                  0                  0
# 5378                   1                  0
# 9643                   0                  0
#
# [20000 rows x 27 columns]

# %%
df_13_encoded = pd.get_dummies(df_12_dropped, columns = ['Protocol'])
df_13_encoded
# Out:
#        level_0  Length                                               Info  \
# 15247    16013   43506  52136  >  5201 [PSH, ACK] Seq=267481998 Ack=1 ...
# 9525     12743      66  5201  >  52136 [ACK] Seq=1 Ack=213724998 Win=3...
# 7468      9020   14546  52136  >  5201 [PSH, ACK] Seq=147958286 Ack=1 ...
# 9196      7816      66  5201  >  52136 [ACK] Seq=1 Ack=129775750 Win=3...
# 8264     16302   36266  52136  >  5201 [PSH, ACK] Seq=271290238 Ack=1 ...
# ...        ...     ...                                                ...
# 3341     17149   40610  52136  >  5201 [ACK] Seq=285479190 Ack=1 Win=6...
# 18250     7689   37714  52136  >  5201 [ACK] Seq=127648638 Ack=1 Win=6...
# 18896     7831      66  5201  >  52136 [ACK] Seq=1 Ack=129992950 Win=3...
# 5378      2104    5858  52136  >  5201 [PSH, ACK] Seq=25857134 Ack=1 W...
# 9643      4669      66  5201  >  52136 [ACK] Seq=1 Ack=77437790 Win=31...
#
#         label                   protocol  flow duration  Total Fwd Packets  \
# 15247  benign  eth:ethertype:ip:tcp:data       0.000020                NaN
# 9525   benign       eth:ethertype:ip:tcp       0.000037           0.000037
# 7468   benign  eth:ethertype:ip:tcp:data       0.000020                NaN
# 9196   benign       eth:ethertype:ip:tcp       0.000015           0.000015
# 8264   benign  eth:ethertype:ip:tcp:data       0.001881                NaN
# ...       ...                        ...            ...                ...
# 3341   benign  eth:ethertype:ip:tcp:data       0.000017                NaN
# 18250  benign  eth:ethertype:ip:tcp:data       0.000019                NaN
# 18896  benign       eth:ethertype:ip:tcp       0.000036           0.000036
# 5378   benign  eth:ethertype:ip:tcp:data       0.000010                NaN
# 9643   benign       eth:ethertype:ip:tcp       0.000025           0.000031
#
#        Fwd Packet Length Max  Fwd Header Length  Bwd Header Length  ...  \
# 15247                  43440                 32              43506  ...
# 9525                       0                 32                 66  ...
# 7468                   14480                 32              14546  ...
# 9196                       0                 32                 66  ...
# 8264                   36200                 32              36266  ...
# ...                      ...                ...                ...  ...
# 3341                   40544                 32              40610  ...
# 18250                  37648                 32              37714  ...
# 18896                      0                 32                 66  ...
# 5378                    5792                 32               5858  ...
# 9643                       0                 32                 66  ...
#
#        source port_52136  source port_99999  Protocol_ASAP  Protocol_AX4000  \
# 15247                  1                  0              0                0
# 9525                   0                  0              0                0
# 7468                   1                  0              0                0
# 9196                   0                  0              0                0
# 8264                   1                  0              0                0
# ...                  ...                ...            ...              ...
# 3341                   1                  0              0                0
# 18250                  1                  0              0                0
# 18896                  0                  0              0                0
# 5378                   1                  0              0                0
# 9643                   0                  0              0                0
#
#        Protocol_DIAMETER  Protocol_DISTCC   Protocol_SABP  Protocol_TCP  \
# 15247                  0                 0              0             1
# 9525                   0                 0              0             1
# 7468                   0                 0              0             1
# 9196                   0                 0              0             1
# 8264                   0                 0              0             1
# ...                  ...               ...            ...           ...
# 3341                   0                 0              0             1
# 18250                  0                 0              0             1
# 18896                  0                 0              0             1
# 5378                   0                 0              0             1
# 9643                   0                 0              0             1
#
#        Protocol_TPKT  Protocol_WOW
# 15247              0             0
# 9525               0             0
# 7468               0             0
# 9196               0             0
# 8264               0             0
# ...              ...           ...
# 3341               0             0
# 18250              0             0
# 18896              0             0
# 5378               0             0
# 9643               0             0
#
# [20000 rows x 34 columns]

# %%
string_columns = df_13_encoded.select_dtypes(include=['object']).columns

# Print the columns with string data type
print("Columns with string values:")
print(string_columns)
# Out:
# Columns with string values:
# Index(['Info', 'label', 'protocol'], dtype='object')

# %%
columns_to_encode = ['Info', 'label', 'protocol']

# Initialize LabelEncoder
label_encoders = {}

# Apply LabelEncoder to each column
for column in columns_to_encode:
    label_encoders[column] = LabelEncoder()
    df_13_encoded[column] = label_encoders[column].fit_transform(df_13_encoded[column])

# %%
df_13_dropped = df_13_encoded.drop(['Total Fwd Packets'], axis=1)
df_13_dropped
# Out:
#        level_0  Length   Info  label  protocol  flow duration  \
# 15247    16013   43506  16889      1         3       0.000020
# 9525     12743      66   3307      1         0       0.000037
# 7468      9020   14546  14225      1         3       0.000020
# 9196      7816      66   1534      1         0       0.000015
# 8264     16302   36266  16983      1         3       0.001881
# ...        ...     ...    ...    ...       ...            ...
# 3341     17149   40610  11241      1         3       0.000017
# 18250     7689   37714   8384      1         3       0.000019
# 18896     7831      66   1540      1         0       0.000036
# 5378      2104    5858  16701      1         3       0.000010
# 9643      4669      66   7252      1         0       0.000025
#
#        Fwd Packet Length Max  Fwd Header Length  Bwd Header Length  \
# 15247                  43440                 32              43506
# 9525                       0                 32                 66
# 7468                   14480                 32              14546
# 9196                       0                 32                 66
# 8264                   36200                 32              36266
# ...                      ...                ...                ...
# 3341                   40544                 32              40610
# 18250                  37648                 32              37714
# 18896                      0                 32                 66
# 5378                    5792                 32               5858
# 9643                       0                 32                 66
#
#        Subflow Bwd Packets  ...  source port_52136  source port_99999  \
# 15247                  NaN  ...                  1                  0
# 9525              0.000037  ...                  0                  0
# 7468                   NaN  ...                  1                  0
# 9196              0.000015  ...                  0                  0
# 8264                   NaN  ...                  1                  0
# ...                    ...  ...                ...                ...
# 3341                   NaN  ...                  1                  0
# 18250                  NaN  ...                  1                  0
# 18896             0.000036  ...                  0                  0
# 5378                   NaN  ...                  1                  0
# 9643              0.000031  ...                  0                  0
#
#        Protocol_ASAP  Protocol_AX4000  Protocol_DIAMETER  Protocol_DISTCC   \
# 15247              0                0                  0                 0
# 9525               0                0                  0                 0
# 7468               0                0                  0                 0
# 9196               0                0                  0                 0
# 8264               0                0                  0                 0
# ...              ...              ...                ...               ...
# 3341               0                0                  0                 0
# 18250              0                0                  0                 0
# 18896              0                0                  0                 0
# 5378               0                0                  0                 0
# 9643               0                0                  0                 0
#
#        Protocol_SABP  Protocol_TCP  Protocol_TPKT  Protocol_WOW
# 15247              0             1              0             0
# 9525               0             1              0             0
# 7468               0             1              0             0
# 9196               0             1              0             0
# 8264               0             1              0             0
# ...              ...           ...            ...           ...
# 3341               0             1              0             0
# 18250              0             1              0             0
# 18896              0             1              0             0
# 5378               0             1              0             0
# 9643               0             1              0             0
#
# [20000 rows x 33 columns]

# %%
df_13 = z_score(df_13_dropped.drop(['label'], axis = 1))
df_13['label'] = df_13_dropped['label']
df_13
# Out:
#         level_0    Length      Info  protocol  flow duration  \
# 15247  1.041543  1.610818  1.193285  0.745623      -0.077100
# 9525   0.475176 -0.858799 -1.159152 -1.336250      -0.050203
# 7468  -0.169650 -0.035594  0.731873  0.745623      -0.077291
# 9196  -0.378184 -0.858799 -1.466240 -1.336250      -0.084121
# 8264   1.091598  1.199215  1.209566  0.745623       2.867284
# ...         ...       ...       ...       ...            ...
# 3341   1.238299  1.446177  0.215037  0.745623      -0.080992
# 18250 -0.400180  1.281536 -0.279803  0.745623      -0.078890
# 18896 -0.375586 -0.858799 -1.465201 -1.336250      -0.050681
# 5378  -1.367507 -0.529517  1.160723  0.745623      -0.092944
# 9643  -0.923247 -0.858799 -0.475868 -1.336250      -0.068583
#
#        Fwd Packet Length Max  Fwd Header Length  Bwd Header Length  \
# 15247               1.610828            0.16147           1.610818
# 9525               -0.858846            0.16147          -0.858799
# 7468               -0.035621            0.16147          -0.035594
# 9196               -0.858846            0.16147          -0.858799
# 8264                1.199216            0.16147           1.199215
# ...                      ...                ...                ...
# 3341                1.446183            0.16147           1.446177
# 18250               1.281538            0.16147           1.281536
# 18896              -0.858846            0.16147          -0.858799
# 5378               -0.529556            0.16147          -0.529517
# 9643               -0.858846            0.16147          -0.858799
#
#        Subflow Bwd Packets  dest port_4040  ...  source port_99999  \
# 15247                  NaN        -0.22941  ...          -0.228564
# 9525             -0.032970        -0.22941  ...          -0.228564
# 7468                   NaN        -0.22941  ...          -0.228564
# 9196             -0.058309        -0.22941  ...          -0.228564
# 8264                   NaN        -0.22941  ...          -0.228564
# ...                    ...             ...  ...                ...
# 3341                   NaN        -0.22941  ...          -0.228564
# 18250                  NaN        -0.22941  ...          -0.228564
# 18896            -0.033330        -0.22941  ...          -0.228564
# 5378                   NaN        -0.22941  ...          -0.228564
# 9643             -0.039267        -0.22941  ...          -0.228564
#
#        Protocol_ASAP  Protocol_AX4000  Protocol_DIAMETER  Protocol_DISTCC   \
# 15247      -0.007071        -0.007071          -0.007071         -0.007071
# 9525       -0.007071        -0.007071          -0.007071         -0.007071
# 7468       -0.007071        -0.007071          -0.007071         -0.007071
# 9196       -0.007071        -0.007071          -0.007071         -0.007071
# 8264       -0.007071        -0.007071          -0.007071         -0.007071
# ...              ...              ...                ...               ...
# 3341       -0.007071        -0.007071          -0.007071         -0.007071
# 18250      -0.007071        -0.007071          -0.007071         -0.007071
# 18896      -0.007071        -0.007071          -0.007071         -0.007071
# 5378       -0.007071        -0.007071          -0.007071         -0.007071
# 9643       -0.007071        -0.007071          -0.007071         -0.007071
#
#        Protocol_SABP  Protocol_TCP  Protocol_TPKT  Protocol_WOW  label
# 15247      -0.007071      0.020004          -0.01     -0.007071      1
# 9525       -0.007071      0.020004          -0.01     -0.007071      1
# 7468       -0.007071      0.020004          -0.01     -0.007071      1
# 9196       -0.007071      0.020004          -0.01     -0.007071      1
# 8264       -0.007071      0.020004          -0.01     -0.007071      1
# ...              ...           ...            ...           ...    ...
# 3341       -0.007071      0.020004          -0.01     -0.007071      1
# 18250      -0.007071      0.020004          -0.01     -0.007071      1
# 18896      -0.007071      0.020004          -0.01     -0.007071      1
# 5378       -0.007071      0.020004          -0.01     -0.007071      1
# 9643       -0.007071      0.020004          -0.01     -0.007071      1
#
# [20000 rows x 33 columns]

# %%
final_df = df_13.copy()
final_df['label'].value_counts()
final_df
# Out:
#         level_0    Length      Info  protocol  flow duration  \
# 15247  1.041543  1.610818  1.193285  0.745623      -0.077100
# 9525   0.475176 -0.858799 -1.159152 -1.336250      -0.050203
# 7468  -0.169650 -0.035594  0.731873  0.745623      -0.077291
# 9196  -0.378184 -0.858799 -1.466240 -1.336250      -0.084121
# 8264   1.091598  1.199215  1.209566  0.745623       2.867284
# ...         ...       ...       ...       ...            ...
# 3341   1.238299  1.446177  0.215037  0.745623      -0.080992
# 18250 -0.400180  1.281536 -0.279803  0.745623      -0.078890
# 18896 -0.375586 -0.858799 -1.465201 -1.336250      -0.050681
# 5378  -1.367507 -0.529517  1.160723  0.745623      -0.092944
# 9643  -0.923247 -0.858799 -0.475868 -1.336250      -0.068583
#
#        Fwd Packet Length Max  Fwd Header Length  Bwd Header Length  \
# 15247               1.610828            0.16147           1.610818
# 9525               -0.858846            0.16147          -0.858799
# 7468               -0.035621            0.16147          -0.035594
# 9196               -0.858846            0.16147          -0.858799
# 8264                1.199216            0.16147           1.199215
# ...                      ...                ...                ...
# 3341                1.446183            0.16147           1.446177
# 18250               1.281538            0.16147           1.281536
# 18896              -0.858846            0.16147          -0.858799
# 5378               -0.529556            0.16147          -0.529517
# 9643               -0.858846            0.16147          -0.858799
#
#        Subflow Bwd Packets  dest port_4040  ...  source port_99999  \
# 15247                  NaN        -0.22941  ...          -0.228564
# 9525             -0.032970        -0.22941  ...          -0.228564
# 7468                   NaN        -0.22941  ...          -0.228564
# 9196             -0.058309        -0.22941  ...          -0.228564
# 8264                   NaN        -0.22941  ...          -0.228564
# ...                    ...             ...  ...                ...
# 3341                   NaN        -0.22941  ...          -0.228564
# 18250                  NaN        -0.22941  ...          -0.228564
# 18896            -0.033330        -0.22941  ...          -0.228564
# 5378                   NaN        -0.22941  ...          -0.228564
# 9643             -0.039267        -0.22941  ...          -0.228564
#
#        Protocol_ASAP  Protocol_AX4000  Protocol_DIAMETER  Protocol_DISTCC   \
# 15247      -0.007071        -0.007071          -0.007071         -0.007071
# 9525       -0.007071        -0.007071          -0.007071         -0.007071
# 7468       -0.007071        -0.007071          -0.007071         -0.007071
# 9196       -0.007071        -0.007071          -0.007071         -0.007071
# 8264       -0.007071        -0.007071          -0.007071         -0.007071
# ...              ...              ...                ...               ...
# 3341       -0.007071        -0.007071          -0.007071         -0.007071
# 18250      -0.007071        -0.007071          -0.007071         -0.007071
# 18896      -0.007071        -0.007071          -0.007071         -0.007071
# 5378       -0.007071        -0.007071          -0.007071         -0.007071
# 9643       -0.007071        -0.007071          -0.007071         -0.007071
#
#        Protocol_SABP  Protocol_TCP  Protocol_TPKT  Protocol_WOW  label
# 15247      -0.007071      0.020004          -0.01     -0.007071      1
# 9525       -0.007071      0.020004          -0.01     -0.007071      1
# 7468       -0.007071      0.020004          -0.01     -0.007071      1
# 9196       -0.007071      0.020004          -0.01     -0.007071      1
# 8264       -0.007071      0.020004          -0.01     -0.007071      1
# ...              ...           ...            ...           ...    ...
# 3341       -0.007071      0.020004          -0.01     -0.007071      1
# 18250      -0.007071      0.020004          -0.01     -0.007071      1
# 18896      -0.007071      0.020004          -0.01     -0.007071      1
# 5378       -0.007071      0.020004          -0.01     -0.007071      1
# 9643       -0.007071      0.020004          -0.01     -0.007071      1
#
# [20000 rows x 33 columns]

# %% [markdown]
# ## Predictions/testing

# %%
def visualize_confusion_matrix(y_true, y_pred):
    conf_matrix = confusion_matrix(y_true, y_pred)
    # Print the confusion matrix using Matplotlib
    fig, ax = plt.subplots(figsize=(5, 5))
    ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
    for i in range(conf_matrix.shape[0]):
        for j in range(conf_matrix.shape[1]):
            ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='x-large')

    plt.xlabel('Predictions', fontsize=18)
    plt.ylabel('Actuals', fontsize=18)
    plt.title('Confusion Matrix', fontsize=18)
    plt.show()

# %%
X = final_df.drop(['label'], axis = 1)
y = final_df['label']

# %%
# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
X_train.fillna(X_train.mean(), inplace=True)
# Out:
# /Users/dashazorkot/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
mlp = MLPClassifier(hidden_layer_sizes=(100, 100), 
                        activation='relu', 
                        solver='sgd', 
                        max_iter=1000, 
                        alpha=0.0001, 
                        batch_size='auto', 
                        verbose=True)

# %%
y_test.value_counts()
# Out:
# 1    3802
# 0     198
# Name: label, dtype: int64

# %% [markdown]
# 1 = BENIGN
# 0 = ATTACK

# %%
# Train MLP model
mlp.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 0.44042772
# Iteration 2, loss = 0.12587434
# Iteration 3, loss = 0.07521794
# Iteration 4, loss = 0.05610673
# Iteration 5, loss = 0.04576438
# Iteration 6, loss = 0.03793526
# Iteration 7, loss = 0.03097063
# Iteration 8, loss = 0.02540289
# Iteration 9, loss = 0.02120969
# Iteration 10, loss = 0.01791713
# Iteration 11, loss = 0.01537260
# Iteration 12, loss = 0.01323466
# Iteration 13, loss = 0.01209208
# Iteration 14, loss = 0.01095570
# Iteration 15, loss = 0.01004168
# Iteration 16, loss = 0.00930585
# Iteration 17, loss = 0.00838151
# Iteration 18, loss = 0.00751878
# Iteration 19, loss = 0.00675292
# Iteration 20, loss = 0.00611488
# Iteration 21, loss = 0.00533142
# Iteration 22, loss = 0.00461995
# Iteration 23, loss = 0.00400229
# Iteration 24, loss = 0.00354643
# Iteration 25, loss = 0.00315722
# Iteration 26, loss = 0.00277611
# Iteration 27, loss = 0.00248864
# Iteration 28, loss = 0.00232839
# Iteration 29, loss = 0.00218966
# Iteration 30, loss = 0.00206944
# Iteration 31, loss = 0.00196120
# Iteration 32, loss = 0.00186416
# Iteration 33, loss = 0.00177636
# Iteration 34, loss = 0.00169662
# Iteration 35, loss = 0.00162351
# Iteration 36, loss = 0.00155625
# Iteration 37, loss = 0.00149402
# Iteration 38, loss = 0.00143646
# Iteration 39, loss = 0.00138296
# Iteration 40, loss = 0.00133358
# Iteration 41, loss = 0.00128702
# Iteration 42, loss = 0.00124391
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(hidden_layer_sizes=(100, 100), max_iter=1000, solver='sgd',
#               verbose=True)

# %%
X_test.fillna(X_test.mean(), inplace=True)

predictions = mlp.predict(X_test)
# Out:
# /Users/dashazorkot/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# Evaluate model performance
print("Number of Iterations: ", mlp.n_iter_)
visualize_confusion_matrix(y_test, predictions)
print("Accuracy: ", accuracy_score(y_test, predictions))
print("Classification Report: ", "\n", classification_report(y_test, predictions))
# Out:
# Number of Iterations:  42
# Accuracy:  0.99925
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       198
#            1       1.00      1.00      1.00      3802
#
#     accuracy                           1.00      4000
#    macro avg       1.00      0.99      1.00      4000
# weighted avg       1.00      1.00      1.00      4000

# %% [markdown]
# # Partie 2 : En temps réel
